# %%
import sys
import os

# Add the correct folder that contains data_utils.py and config.py
sys.path.append(r"C:\Users\sheet\github\citibike\src")

# Now import everything you need from src
from data_utils import load_and_process_citibike_data_from_local, transform_raw_data_into_ts_data
import config as config

# Other imports
import hopsworks
from hsfs.feature import Feature
from datetime import datetime, timedelta
from pathlib import Path
from typing import List, Optional, Tuple, Union
import numpy as np
import pandas as pd
import requests

# %%
# Step 2: Load Data from Local
print("📂 Loading Citi Bike data (2023)...")
data = load_and_process_citibike_data_from_local(
    year=2023,
    months=[1,2,3,4,5,6],
    base_path=config.LOCAL_CITIBIKE_DATA_PATH
)
# Out:
# 📂 Loading Citi Bike data (2023)...
# 2025-05-10 12:54:53,553 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 12:54:59,130 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 12:55:07,105 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 12:55:12,408 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 12:55:19,619 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 12:55:25,157 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 12:55:30,352 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 12:55:35,739 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 12:55:43,502 WARNING: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 12:55:50,180 WARNING: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 12:55:57,672 WARNING: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 12:56:02,551 WARNING: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 12:56:08,436 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 12:56:14,823 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 12:56:20,417 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 12:56:25,411 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 12:56:30,558 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 12:56:36,352 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 12:56:43,097 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 12:56:49,740 WARNING: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 12:56:56,590 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 12:57:01,245 WARNING: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 12:57:04,376 WARNING: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 12:57:08,821 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 12:57:13,667 WARNING: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 12:57:18,662 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 12:57:25,689 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 12:57:31,949 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 12:57:38,275 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 12:57:42,438 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 12:57:47,851 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 12:57:52,679 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 12:57:57,642 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#
# 2025-05-10 12:58:00,372 WARNING: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
print("✅ Loaded data shape:", data.shape)
display(data.head())
# Out:
# ✅ Loaded data shape: (157285, 14)
#             ride_id  rideable_type         pickup_datetime  \
# 0  A46D077151843D7B   classic_bike 2023-01-16 10:39:54.386
# 1  233875BAED2E02D0   classic_bike 2023-01-12 16:55:30.755
# 2  8DD222EA1A1B0BC9  electric_bike 2023-01-08 19:32:25.647
# 3  58976A4F584F8D28   classic_bike 2023-01-27 20:01:52.897
# 4  FDD4C1E89A26727C   classic_bike 2023-01-13 18:02:38.160
#
#                   ended_at     start_station_name pickup_location_id  \
# 0  2023-01-16 10:45:18.005  West St & Chambers St            5329.03
# 1  2023-01-12 17:04:03.688  West St & Chambers St            5329.03
# 2  2023-01-08 19:42:00.382  West St & Chambers St            5329.03
# 3  2023-01-27 20:08:58.118  West St & Chambers St            5329.03
# 4  2023-01-13 18:11:22.139  West St & Chambers St            5329.03
#
#   end_station_name end_station_id  start_lat  start_lng    end_lat    end_lng  \
# 0   West Thames St        5114.06  40.717548 -74.013221  40.708347 -74.017134
# 1   West Thames St        5114.06  40.717548 -74.013221  40.708347 -74.017134
# 2   West Thames St        5114.06  40.717618 -74.013071  40.708347 -74.017134
# 3   West Thames St        5114.06  40.717548 -74.013221  40.708347 -74.017134
# 4   West Thames St        5114.06  40.717548 -74.013221  40.708347 -74.017134
#
#   member_casual                     source_file
# 0        member  202301-citibike-tripdata_1.csv
# 1        member  202301-citibike-tripdata_1.csv
# 2        member  202301-citibike-tripdata_1.csv
# 3        member  202301-citibike-tripdata_1.csv
# 4        member  202301-citibike-tripdata_1.csv

# %%
# Step 3: Preprocess Data
data["pickup_datetime"] = pd.to_datetime(data["pickup_datetime"], errors="coerce")
data = data.dropna(subset=["pickup_datetime", "pickup_location_id"])
data["pickup_location_id"] = data["pickup_location_id"].astype(str)
data["pickup_hour"] = data["pickup_datetime"].dt.floor("h")

# %%
# Step 4: Transform into Hourly Time-Series
ts_data = transform_raw_data_into_ts_data(data)
print("✅ Transformed time-series shape:", ts_data.shape)
display(ts_data.head())
# Out:
# ✅ Transformed time-series shape: (13287, 3)
#           pickup_hour pickup_location_id  rides
# 0 2022-12-28 11:00:00            5329.03      2
# 1 2022-12-28 12:00:00            5329.03      0
# 2 2022-12-28 13:00:00            5329.03      0
# 3 2022-12-28 14:00:00            5329.03      0
# 4 2022-12-28 15:00:00            5329.03      0

# %%
# Step 5: Check Aggregation Info
print("📅 Date range:", ts_data.pickup_hour.min(), "→", ts_data.pickup_hour.max())
print("🧠 Nulls present:")
display(ts_data.isnull().sum())
# Out:
# 📅 Date range: 2022-12-28 11:00:00 → 2023-06-30 23:00:00
# 🧠 Nulls present:
# pickup_hour           0
# pickup_location_id    0
# rides                 0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# Step 6: Visualize Time-Series
plt.figure(figsize=(12, 5))
for location_id in ts_data.pickup_location_id.unique():
    subset = ts_data[ts_data.pickup_location_id == location_id]
    plt.plot(subset.pickup_hour, subset.rides, label=f"Location {location_id}")
plt.legend()
plt.title("📈 Hourly Ride Counts for Top Stations")
plt.xlabel("Time")
plt.ylabel("Rides")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# 2025-05-10 13:04:49,880 WARNING: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#
# 2025-05-10 13:04:50,031 WARNING: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.

# %%
csv_path = config.TRANSFORMED_DATA_DIR / "jan_jun_2023_ts_data.csv"
ts_data.to_csv(csv_path, index=False)
print(f"💾 Saved to: {csv_path}")
# Out:
# 💾 Saved to: C:\Users\sheet\github\citibike\data\transformed\jan_jun_2023_ts_data.csv

# %%
# Step 8: Connect to Hopsworks and Register Feature Group
print("🔐 Logging in to Hopsworks ...")
project = hopsworks.login(
    project=config.HOPSWORKS_PROJECT_NAME,
    api_key_value=config.HOPSWORKS_API_KEY
)
fs = project.get_feature_store()
# Out:
# 🔐 Logging in to Hopsworks ...
# 2025-05-10 13:04:57,328 INFO: Initializing external client
# 2025-05-10 13:04:57,330 INFO: Base URL: https://c.app.hopsworks.ai:443
# 2025-05-10 13:04:58,171 WARNING: UserWarning: The installed hopsworks client version 4.1.8 may not be compatible with the connected Hopsworks backend version 4.2.0.
# To ensure compatibility please install the latest bug fix release matching the minor version of your backend (4.2) by running 'pip install hopsworks==4.2.*'
# 2025-05-10 13:04:59,577 INFO: Python Engine initialized.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/1214674

# %%
# Define schema and feature group
schema = [
    Feature("pickup_hour", "timestamp"),
    Feature("pickup_location_id", "string"),
    Feature("rides", "int")
]

fg = fs.get_or_create_feature_group(
    name=config.FEATURE_GROUP_NAME,
    version=config.FEATURE_GROUP_VERSION,
    description="Hourly Citi Bike rides (March 2023)",
    primary_key=["pickup_hour", "pickup_location_id"],
    event_time="pickup_hour",
    online_enabled=False,
    features=schema
)

# %%
# Cast dtypes and insert
print("📤 Writing to Hopsworks...")
ts_data["pickup_location_id"] = ts_data["pickup_location_id"].astype(str)
ts_data["rides"] = ts_data["rides"].astype("int64")
fg.insert(ts_data, write_options={"wait_for_job": True})
print("✅ Successfully registered with Hopsworks")
# Out:
# 📤 Writing to Hopsworks...
# Uploading Dataframe: 100.00% |█████████████████████████| Rows 13287/13287 | Elapsed Time: 00:01 | Remaining Time: 00:00
# Launching job: citibike_hourly_features_1_offline_fg_materialization
# Job started successfully, you can follow the progress at
# https://c.app.hopsworks.ai:443/p/1214674/jobs/named/citibike_hourly_features_1_offline_fg_materialization/executions
# 2025-05-10 13:05:49,983 INFO: Waiting for execution to finish. Current state: SUBMITTED. Final status: UNDEFINED
# 2025-05-10 13:05:53,148 INFO: Waiting for execution to finish. Current state: RUNNING. Final status: UNDEFINED
# 2025-05-10 13:07:41,110 INFO: Waiting for execution to finish. Current state: AGGREGATING_LOGS. Final status: SUCCEEDED
# 2025-05-10 13:07:41,298 INFO: Waiting for log aggregation to finish.
# 2025-05-10 13:07:49,883 INFO: Execution finished successfully.
# ✅ Successfully registered with Hopsworks
